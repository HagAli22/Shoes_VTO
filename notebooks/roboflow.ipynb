# %%
# 1. Install Roboflow
# !pip install -q roboflow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.0/285.0 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 18.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 53.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 100.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 3.6 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="AXDmB9TCDtnmUGce478D")

project = (
    rf.workspace("novagatess-workspace-vutpv")
      .project("fingers_keypoint")
)
version = project.version(10)

print(version)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# {
#   "name": "fingers_keypoint",
#   "type": "keypoint-detection",
#   "version": "10",
#   "augmentation": {},
#   "created": 1789594510.634,
#   "preprocessing": {
#     "filter-tags": {
#       "tags": {
#         "::none::": {
#           "omit": true
#         },
#         "Teh_Marbuta": {
#           "omit": true
#         },
#         "The_Marbuta": {
#           "omit": true
#         },
#         "anotacao-ruim": {
#           "omit": true
#         },
#         "closed": {
#           "omit": true
#         },
#         "fingers": {
#           "omit": true
#         },
#         "first_1000": {
#           "omit": true
#         },
#         "left": {
#           "omit": true
#         },
#         "neils": {
#           "omit": true
#         },
#         "new1": {
#           "omit": true
#         },
#         "right": {
#           "omit": true
#         }
#       }
#     }
#   },
#   "splits": {
# ...

# %%
dataset = project.version(11).download(
    "yolov8",
    location=r"F:/Machine learning/Shoes_VTO/data/shoes_v2"
)
# Out:
# Exporting format yolov8 in progress : 95.0%
# Version export complete for yolov8 format
# ...
# Extracting Dataset Version Zip to F:/Machine learning/Shoes_VTO/data/shoes_v2 in yolov8:: 100%|██████████| 612/612 [00:00<00:00, 1704.19it/s]
